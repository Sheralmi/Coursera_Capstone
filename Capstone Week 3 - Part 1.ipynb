# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

# !conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

# for webscraping import Beautiful Soup 
from bs4 import BeautifulSoup

import xml

# !conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
# Libraries imported.

# %%
#The Wikipedia page was changed on November, 2019
#We will use the older version
url = "https://en.wikipedia.org/w/index.php?title=List_of_postal_codes_of_Canad%D7%A9a:_M&oldid=926306543"
res = requests.get(url)

# %%
soup = BeautifulSoup(res.content,'lxml')
table = soup.find_all('table')[0]
df = pd.read_html(str(table))
data = pd.read_json(df[0].to_json(orient='records'))
df = data[data['Borough'] != 'Not assigned']
df.head()
# Out:
#   Postcode           Borough     Neighbourhood
# 2      M3A        North York         Parkwoods
# 3      M4A        North York  Victoria Village
# 4      M5A  Downtown Toronto      Harbourfront
# 5      M6A        North York  Lawrence Heights
# 6      M6A        North York    Lawrence Manor

# %%
#Grouping by Borough and Postcode
df = df.groupby(['Postcode','Borough'], as_index=False).agg(','.join)
df = df.sample(frac=1).reset_index(drop=True)
df
# Out:
#     Postcode           Borough  \
# 0        M3N        North York
# 1        M6K      West Toronto
# 2        M2P        North York
# 3        M1C       Scarborough
# 4        M4X  Downtown Toronto
# 5        M5R   Central Toronto
# 6        M9R         Etobicoke
# 7        M5J  Downtown Toronto
# 8        M4B         East York
# 9        M9V         Etobicoke
# 10       M3B        North York
# 11       M2N        North York
# 12       M6M              York
# 13       M1M       Scarborough
# 14       M6H      West Toronto
# 15       M4L      East Toronto
# 16       M2J        North York
# 17       M5G  Downtown Toronto
# 18       M4R   Central Toronto
# 19       M4E      East Toronto
# 20       M8Y         Etobicoke
# 21       M5A  Downtown Toronto
# 22       M1T       Scarborough
# 23       M5C  Downtown Toronto
# 24       M5W  Downtown Toronto
# 25       M5B  Downtown Toronto
# 26       M4A        North York
# 27       M1S       Scarborough
# 28       M5S  Downtown Toronto
# 29       M4P   Central Toronto
# 30       M5T  Downtown Toronto
# 31       M2L        North York
# 32       M2R        North York
# 33       M1N       Scarborough
# 34       M4S   Central Toronto
# 35       M4G         East York
# 36       M7R       Mississauga
# 37       M8Z         Etobicoke
# 38       M6P      West Toronto
# 39       M1P       Scarborough
# 40       M5L  Downtown Toronto
# 41       M2K        North York
# 42       M1E       Scarborough
# 43       M7A      Queen's Park
# 44       M5X  Downtown Toronto
# 45       M3K        North York
# 46       M6R      West Toronto
# 47       M4Y  Downtown Toronto
# 48       M4N   Central Toronto
# 49       M4W  Downtown Toronto
# 50       M7Y      East Toronto
# 51       M9P         Etobicoke
# 52       M6B        North York
# 53       M3J        North York
# 54       M4J         East York
# 55       M4H         East York
# 56       M1K       Scarborough
# 57       M1J       Scarborough
# 58       M5P   Central Toronto
# 59       M6E              York
# 60       M5V  Downtown Toronto
# 61       M6A        North York
# 62       M6G  Downtown Toronto
# 63       M3M        North York
# 64       M3A        North York
# 65       M2H        North York
# 66       M3L        North York
# 67       M9L        North York
# 68       M9N              York
# 69       M3H        North York
# 70       M6J      West Toronto
# 71       M8V         Etobicoke
# 72       M1L       Scarborough
# 73       M8X         Etobicoke
# 74       M4K      East Toronto
# 75       M9A      Queen's Park
# 76       M5H  Downtown Toronto
# 77       M6L        North York
# 78       M3C        North York
# 79       M1G       Scarborough
# 80       M9M        North York
# 81       M5E  Downtown Toronto
# 82       M1X       Scarborough
# 83       M9B         Etobicoke
# 84       M4V   Central Toronto
# 85       M6N              York
# 86       M9C         Etobicoke
# 87       M4M      East Toronto
# 88       M1B       Scarborough
# 89       M8W         Etobicoke
# 90       M4C         East York
# 91       M1W       Scarborough
# 92       M1R       Scarborough
# 93       M6C              York
# 94       M9W         Etobicoke
# 95       M6S      West Toronto
# 96       M5M        North York
# 97       M1V       Scarborough
# 98       M5K  Downtown Toronto
# 99       M5N   Central Toronto
# 100      M2M        North York
# 101      M4T   Central Toronto
# 102      M1H       Scarborough
#
#                                          Neighbourhood
# 0                                  Downsview Northwest
# 1           Brockton,Exhibition Place,Parkdale Village
# 2                                      York Mills West
# 3                 Highland Creek,Rouge Hill,Port Union
# 4                           Cabbagetown,St. James Town
# 5                    The Annex,North Midtown,Yorkville
# 6    Kingsview Village,Martin Grove Gardens,Richvie...
# 7      Harbourfront East,Toronto Islands,Union Station
# 8                       Woodbine Gardens,Parkview Hill
# 9    Albion Gardens,Beaumond Heights,Humbergate,Jam...
# 10                                     Don Mills North
# 11                                    Willowdale South
# 12         Del Ray,Keelesdale,Mount Dennis,Silverthorn
# 13       Cliffcrest,Cliffside,Scarborough Village West
# 14                         Dovercourt Village,Dufferin
# 15                       The Beaches West,India Bazaar
# 16                          Fairview,Henry Farm,Oriole
# 17                                  Central Bay Street
# 18                                  North Toronto West
# 19                                         The Beaches
# 20   Humber Bay,King's Mill Park,Kingsway Park Sout...
# 21                                        Harbourfront
# 22               Clarks Corners,Sullivan,Tam O'Shanter
# 23                                      St. James Town
# 24                     Stn A PO Boxes 25 The Esplanade
# 25                             Ryerson,Garden District
# 26                                    Victoria Village
# 27                                           Agincourt
# 28                       Harbord,University of Toronto
# 29                                    Davisville North
# 30             Chinatown,Grange Park,Kensington Market
# 31                             Silver Hills,York Mills
# 32                                     Willowdale West
# 33                          Birch Cliff,Cliffside West
# 34                                          Davisville
# 35                                             Leaside
# 36               Canada Post Gateway Processing Centre
# 37   Kingsway Park South West,Mimico NW,The Queensw...
# 38                        High Park,The Junction South
# 39   Dorset Park,Scarborough Town Centre,Wexford He...
# 40                       Commerce Court,Victoria Hotel
# 41                                     Bayview Village
# 42                     Guildwood,Morningside,West Hill
# 43                                        Not assigned
# 44               First Canadian Place,Underground city
# 45                          CFB Toronto,Downsview East
# 46                               Parkdale,Roncesvalles
# 47                                Church and Wellesley
# 48                                       Lawrence Park
# 49                                            Rosedale
# 50   Business Reply Mail Processing Centre 969 Eastern
# 51                                           Westmount
# 52                                           Glencairn
# 53                      Northwood Park,York University
# 54                                        East Toronto
# 55                                    Thorncliffe Park
# 56           East Birchmount Park,Ionview,Kennedy Park
# 57                                 Scarborough Village
# 58                  Forest Hill North,Forest Hill West
# 59                                 Caledonia-Fairbanks
# 60   CN Tower,Bathurst Quay,Island airport,Harbourf...
# 61                     Lawrence Heights,Lawrence Manor
# 62                                            Christie
# 63                                   Downsview Central
# 64                                           Parkwoods
# 65                                   Hillcrest Village
# 66                                      Downsview West
# 67                                       Humber Summit
# 68                                              Weston
# 69       Bathurst Manor,Downsview North,Wilson Heights
# 70                             Little Portugal,Trinity
# 71          Humber Bay Shores,Mimico South,New Toronto
# 72                       Clairlea,Golden Mile,Oakridge
# 73         The Kingsway,Montgomery Road,Old Mill North
# 74                         The Danforth West,Riverdale
# 75                                        Queen's Park
# 76                              Adelaide,King,Richmond
# 77                    Downsview,North Park,Upwood Park
# 78                     Flemingdon Park,Don Mills South
# 79                                              Woburn
# 80                                     Emery,Humberlea
# 81                                         Berczy Park
# 82                                         Upper Rouge
# 83   Cloverdale,Islington,Martin Grove,Princess Gar...
# 84   Deer Park,Forest Hill SE,Rathnelly,South Hill,...
# 85                        The Junction North,Runnymede
# 86   Bloordale Gardens,Eringate,Markland Wood,Old B...
# 87                                     Studio District
# 88                                       Rouge,Malvern
# 89                               Alderwood,Long Branch
# 90                                    Woodbine Heights
# 91                                     L'Amoreaux West
# 92                                    Maryvale,Wexford
# 93                                  Humewood-Cedarvale
# 94                                           Northwest
# 95                                   Runnymede,Swansea
# 96                    Bedford Park,Lawrence Manor East
# 97   Agincourt North,L'Amoreaux East,Milliken,Steel...
# 98             Design Exchange,Toronto Dominion Centre
# 99                                            Roselawn
# 100                             Newtonbrook,Willowdale
# 101                         Moore Park,Summerhill East
# 102                                          Cedarbrae

# %%
df.shape
# Out:
# (103, 3)
